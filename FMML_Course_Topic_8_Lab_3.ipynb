# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavipsbr/fmml_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 17:49:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  80.9MB/s    in 0.9s
#
# 2024-03-26 17:49:30 (80.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14930   1309.5391v1  Colour is a key component in the successful di...    cs
# 23011  1801.09667v1  In the stochastic bandit problem, the goal is ...  stat
# 13696   1112.2183v1  Customer Relationship Management becomes a lea...    cs
# 2928   1707.04046v4  Methods that align distributions by minimizing...    cs
# 3301   1501.04656v2  Determining the 3D structures of biological mo...  stat
# ...             ...                                                ...   ...
# 26092  1608.06434v1  This paper focuses on the problem of generatin...    cs
# 34957   1402.4036v1  Memristors have been suggested as a novel rout...    cs
# 38055   1108.5520v1  Sentiment analysis is a new area in text analy...  stat
# 4418   1707.00755v1  We present a neighborhood similarity layer (NS...    cs
# 22956  1711.08451v1  The estimation of optimal treatment regimes is...  stat
#
#                                                    title  year  \
# 14930  Even the Abstract have Colour: Consensus in Wo...  2013
# 23011  Information Directed Sampling and Bandits with...  2018
# 13696  The Expert System Designed to Improve Customer...  2011
# 2928   Stable Distribution Alignment Using the Dual o...  2017
# 3301   Microscopic Advances with Large-Scale Learning...  2015
# ...                                                  ...   ...
# 26092  Convolutional Network for Attribute-driven and...  2016
# 34957  Is Spiking Logic the Route to Memristor-Based ...  2014
# 38055  A sentiment analysis of Singapore Presidential...  2011
# 4418   Appearance invariance in convolutional network...  2017
# 22956  Causal nearest neighbor rules for optimal trea...  2017
#
#                                                 keywords
# 14930  [component, successful, dissemination, informa...
# 23011  [stochastic, evaluations, typically, observati...
# 13696  [relationship, management, competitive, enviro...
# 2928   [distributions, minimizing, adversarial, impre...
# 3301   [determining, structures, biological, molecule...
# ...                                                  ...
# 26092  [generating, attributes, generation, generated...
# 34957  [memristors, suggested, neuromorphic, computin...
# 38055  [sentiment, analytics, understanding, manageme...
# 4418   [neighborhood, similarity, appearance, invaria...
# 22956  [estimation, treatment, considerable, precisio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14930    [component, successful, dissemination, informa...
# 23011    [stochastic, evaluations, typically, observati...
# 13696    [relationship, management, competitive, enviro...
# 2928     [distributions, minimizing, adversarial, impre...
# 3301     [determining, structures, biological, molecule...
#                                ...
# 21876    [synthesis, represented, combinations, diction...
# 2240     [applications, structure, probabilistic, graph...
# 29608    [surveillance, necessity, surveillance, perfor...
# 21992    [statistical, dependency, dependency, variable...
# 20081    [researches, mathematical, intervals, characte...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8814 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="42c32e31-ee28-4558-82f5-d49153fc1d3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42c32e31-ee28-4558-82f5-d49153fc1d3f")) {                    Plotly.newPlot(                        "42c32e31-ee28-4558-82f5-d49153fc1d3f",                        [{"x":["associations","dissemination","crowdsourcing","annotations","visualization","association","associated","especially","information","successful","coherence","linguistic","marketing","complemented","component","emotional","appropriate","consensus","comprehensive","approaches","observation","regression","typically","framework","confidence","shortcomings","inequalities","algorithms","distribution","reproducing","explicitly","functions","surrogate","formulate","outperform","introduce","stochastic","evaluation","heteroscedastic","generalize","construct","probability","distributions","concentration","evaluations","randomized","depending","separable","frequentist","uniformly","comparable","demonstrate","homoscedastic","empirically","optimization","independent","satisfies","satisfaction","performance","technique","customers","objective","competitive","requirements","environment","different","artificial","improving","selection","decisions","validated","capability","businesses","knowledge","developed","management","relationship","presented","collected","adversarial","improvement","restricted","convergence","alignment","discrepancy","minimizing","replacing","resulting","formulation","impressive","initialization","difficult","hyperparameter","maximization","adaptation","iterative","discriminators","investigate","restrictions","monotonic","synthetic","connections","hypothesis","procedure","desirable","empirical","determining","formulated","computational","represents","probabilistic","discovery","reasonable","microscopic","introduces","application","structure","significantly","structures","reconstruct","challenging","techniques","molecules","biological","estimation","recovering","promising","dramatically","specifically","benchmark","intelligent","constraint","optimisations","implementations","instances","chronological","comparison","backtracking","implementation","strategies","programming","furthermore","presentation","intelligence","processing","expectations","conditional","bootstrap","simultaneous","parameter","theoretical","dimensional","multiplier","difference","quantities","developing","procedures","expectation","uncertainties","establish","computation","established","assessing","asymptotically","composite","estimator","guarantees","inference","distributed","preserves","approximation","efficiency","dimension","intervals","assumptions","curvature","inferential","existence","penalized","exponentially","parameters","complexity","outperforms","handwritten","partitioning","remaining","demonstrates","preliminary","recognition","practical","scalability","producing","computations","generally","classification","researchers","computing","applications","experiment","processors"],"y":[12,3,13,59,28,21,122,119,671,68,18,59,7,3,94,10,93,20,66,434,66,106,99,527,41,11,10,598,227,7,73,203,16,51,106,331,117,278,1,50,87,146,122,9,69,17,34,15,1,13,91,586,0,77,328,129,7,25,895,252,14,164,104,52,101,773,136,104,179,55,27,47,4,339,206,49,83,174,75,105,140,43,115,58,14,39,10,150,78,19,25,161,4,30,68,70,2,166,12,13,143,56,52,119,33,187,36,39,282,48,163,52,29,3,61,250,303,277,133,33,254,374,7,58,213,23,108,18,147,203,60,107,2,34,116,2,146,5,125,114,122,153,9,82,282,6,113,3,23,110,158,205,1,45,10,67,43,34,10,52,160,38,24,11,12,31,62,208,110,10,107,160,60,15,72,10,2,36,3,25,233,216,250,29,23,17,56,44,383,140,38,25,35,68,505,60,131,411,75,6],"type":"bar"},{"x":["associations","dissemination","crowdsourcing ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>IDSA</span> <span style='background-color:rgba(0, 255, 0, 0.935483870967742);'>Intelligent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>Sensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>For</span> <span style=''>Target</span> <span style=''>Tracking</span> <span style=''>With</span> <span style=''>Wireless</span> <span style=''>Sensor</span> <span style=''>Network</span> <br/><br/><span style=''>One</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Wireless</span> <span style=''>Sensor</span> <span style=''>Network(WSN)</span> <span style=''>is</span> <span style=''>target</span> <span style=''>tracking</span> <span style=''>the</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converging</span> <span style=''>to</span> <span style=''>an</span> <span style=''>event</span> <span style=''>or</span> <span style=''>object</span> <span style=''>in</span> <span style=''>an</span> <span style=''>area</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>sensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style=''>protocol</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicted</span> <span style=''>location</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.935483870967742);'>Intelligent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>Sensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>(IDSA)</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>predicts</span> <span style=''>the</span> <span style=''>location</span> <span style=''>of</span> <span style=''>target</span> <span style=''>in</span> <span style=''>the</span> <span style=''>next</span> <span style=''>time</span> <span style=''>interval</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>current</span> <span style=''>location</span> <span style=''>and</span> <span style=''>movement</span> <span style=''>history</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>done</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.7263157894736842);'>intelligence</span> <span style=''>The</span> <span style=''>fewest</span> <span style='background-color:rgba(0, 255, 0, 0.4423076923076923);'>essential</span> <span style=''>number</span> <span style=''>of</span> <span style=''>sensor</span> <span style=''>nodes</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicted</span> <span style=''>location</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Strategies</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Bayesian</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>MKL</span> <br/><br/><span style=''>Multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>(MKL)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>received</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>MKL</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>either</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>on</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>weights</span> <span style=''>or</span> <span style=''>block</span> <span style=''>norm</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>which</span> <span style=''>is</span> <span style=''>more</span> <span style=''>common</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>mapped</span> <span style=''>to</span> <span style=''>each</span> <span style=''>other</span> <span style=''>through</span> <span style=''>a</span> <span style=''>concave</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjugate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operation</span> <span style=''>When</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>weight</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizer</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>behind</span> <span style=''>MKL</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style=''>model</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>learning</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Stop</span> <span style=''>Wasting</span> <span style=''>My</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Gradients</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Practical</span> <span style=''>SVRG</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315791);'>improving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>stochastic</span> <span style=''>variance</span> <span style=''>reduced</span> <span style=''>gradient</span> <span style=''>(SVRG)</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>first</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.31343283582089543);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserved</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreasing</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>errors</span> <span style=''>in</span> <span style=''>the</span> <span style=''>control</span> <span style=''>variate</span> <span style=''>and</span> <span style=''>use</span> <span style=''>this</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>SVRG</span> <span style=''>that</span> <span style=''>use</span> <span style=''>growing</span> <span style=''>batch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculations</span> <span style=''>required</span> <span style=''>in</span> <span style=''>the</span> <span style=''>early</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>We</span> <span style=''>further</span> <span style=''>(i)</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>support</span> <span style=''>vectors</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>later</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>(ii)</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>commonly</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.504);'>regularized</span> <span style=''>SVRG</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justified</span> <span style=''>and</span> <span style=''>improves</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.31343283582089543);'>convergence</span> <span style=''>rate</span> <span style=''>(iii)</span> <span style=''>consider</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternate</span> <span style=''>mini</span> <span style=''>batch</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consistency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Robustness</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Localized</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <br/><br/><span style=''>The</span> <span style=''>massive</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>used</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>patters</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>runtime</span> <span style=''>and</span> <span style=''>storage</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capacities</span> <span style=''>Local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>might</span> <span style=''>help</span> <span style=''>to</span> <span style=''>relieve</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>From</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>point</span> <span style=''>of</span> <span style=''>view</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>allow</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additionally</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>ways</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>analyses</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>localized</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>of</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SVMs)</span> <span style=''>and</span> <span style=''>methods</span> <span style=''>close</span> <span style=''>to</span> <span style=''>them</span> <span style=''>We</span> <span style=''>will</span> <span style=''>show</span> <span style=''>there</span> <span style=''>that</span> <span style=''>locally</span> <span style=''>learnt</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>give</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09985632183908046)
# 	experimental (0.13685344827586207)
# 	architecture (0.08189655172413793)
# 	information (0.24102011494252873)
# 	segmentation (0.07794540229885058)
# 	representation (0.14260057471264367)
# 	detection (0.12931034482758622)
# 	convolutional (0.1257183908045977)
# 	different (0.2776580459770115)
# 	recognition (0.13757183908045978)
#
# Some Statistics words are:
# 	stochastic (0.12946428571428573)
# 	theoretical (0.14732142857142858)
# 	estimation (0.1701388888888889)
# 	variables (0.1433531746031746)
# 	distribution (0.18055555555555555)
# 	algorithm (0.3844246031746032)
# 	statistical (0.16121031746031747)
# 	dimensional (0.19295634920634921)
# 	inference (0.20436507936507936)
# 	regression (0.18898809523809523)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bee0b94-9814-453c-8a14-72e5e044b76b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bee0b94-9814-453c-8a14-72e5e044b76b")) {                    Plotly.newPlot(                        "5bee0b94-9814-453c-8a14-72e5e044b76b",                        [{"x":["associations","dissemination","crowdsourcing","annotations","visualization","association","associated","especially","information","successful","coherence","linguistic","marketing","complemented","component","emotional","appropriate","consensus","comprehensive","approaches","observation","regression","typically","framework","confidence","shortcomings","inequalities","algorithms","distribution","reproducing","explicitly","functions","surrogate","formulate","outperform","introduce","stochastic","evaluation","heteroscedastic","generalize","construct","probability","distributions","concentration","evaluations","randomized","depending","separable","frequentist","uniformly","comparable","demonstrate","homoscedastic","empirically","optimization","independent","satisfies","satisfaction","performance","technique","customers","objective","competitive","requirements","environment","different","artificial","improving","selection","decisions","validated","capability","businesses","knowledge","developed","management","relationship","presented","collected","adversarial","improvement","restricted","convergence","alignment","discrepancy","minimizing","replacing","resulting","formulation","impressive","initialization","difficult","hyperparameter","maximization","adaptation","iterative","discriminators","investigate","restrictions","monotonic","synthetic","connections","hypothesis","procedure","desirable","empirical","determining","formulated","computational","represents","probabilistic","discovery","reasonable","microscopic","introduces","application","structure","significantly","structures","reconstruct","challenging","techniques","molecules","biological","estimation","recovering","promising","dramatically","specifically","benchmark","intelligent","constraint","optimisations","implementations","instances","chronological","comparison","backtracking","implementation","strategies","programming","furthermore","presentation","intelligence","processing","expectations","conditional","bootstrap","simultaneous","parameter","theoretical","dimensional","multiplier","difference","quantities","developing","procedures","expectation","uncertainties","establish","computation","established","assessing","asymptotically","composite","estimator","guarantees","inference","distributed","preserves","approximation","efficiency","dimension","intervals","assumptions","curvature","inferential","existence","penalized","exponentially","parameters","complexity","outperforms","handwritten","partitioning","remaining","demonstrates","preliminary","recognition","practical","scalability","producing","computations","generally","classification","researchers","computing","applications","experiment","processors","incorrectly","concluded","satellite","shielding","monitoring","reflection","situations","satellites","positioning","advantage","completely","conditions","technology","transform","corresponds","navigation","effectiveness","expressive","properties","representation","qualitative","meaningfully","multiplication","simulation","simulations","impossible","inherently","soundness","employing","algorithm","operating","constancy","completeness","construction","containing","simulators","predictions","constraints","guarantee","restriction","transition","simulator","derivative","vocabulary","relations","incomplete","gradients","automated","augmented","experiments","optimizing","efficiently","competitiveness","likelihood","gauss ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	homoscedastic
# 	narrowing
# 	selectors
# 	misspecified
# 	cytometric
# 	cytometry
# 	semiparametric
# 	nonparanormal
# 	minimizers
# 	checkable
# 	impossibility
# 	distributionally
# 	robustification
# 	diverging
# 	terminate
# 	separators
# 	noninformative
# 	electroencephalography
# 	schizophrenia
# 	blockmodel
# Some words which never appear in Statistics papers:
# 	emotional
# 	optimisations
# 	concluded
# 	shielding
# 	reflection
# 	soundness
# 	constancy
# 	mammogram
# 	corroborated
# 	recognizer
# 	situational
# 	reconfigured
# 	gutenberg
# 	realizing
# 	cityscapes
# 	stereotypical
# 	fixations
# 	recurring
# 	triangulation
# 	inheritance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082329007798292e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
